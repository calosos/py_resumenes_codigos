# %% [markdown]
# <a href="https://colab.research.google.com/github/calosos/py_resumenes_codigos/blob/main/Pandas_Ortiz_Suarez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/para borrar/Summer-Olympic-medals-1976-to-2008.csv',  encoding='latin-1')
df.head(3)
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
#
#                 Athlete Gender Country_Code        Country Event_gender  \
# 0       KÖHLER, Christa  Women          GDR   East Germany            W
# 1   KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2  BOGGS, Philip George    Men          USA  United States            M
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold

# %%
year_index = pd.DatetimeIndex(df['Year'])
year_index
# Out:
# DatetimeIndex(['1970-01-01 00:00:00.000001976',
#                '1970-01-01 00:00:00.000001976',
#                '1970-01-01 00:00:00.000001976',
#                '1970-01-01 00:00:00.000001976',
#                '1970-01-01 00:00:00.000001976',
#                '1970-01-01 00:00:00.000001976',
#                '1970-01-01 00:00:00.000001976',
#                '1970-01-01 00:00:00.000001976',
#                '1970-01-01 00:00:00.000001976',
#                '1970-01-01 00:00:00.000001976',
#                ...
#                '1970-01-01 00:00:00.000002008',
#                '1970-01-01 00:00:00.000002008',
#                '1970-01-01 00:00:00.000002008',
#                '1970-01-01 00:00:00.000002008',
#                '1970-01-01 00:00:00.000002008',
#                '1970-01-01 00:00:00.000002008',
#                '1970-01-01 00:00:00.000002008',
#                '1970-01-01 00:00:00.000002008',
#                '1970-01-01 00:00:00.000002008',
# ...

# %%
split_names = df['Athlete'].str.split(', ', expand = True)
last_name=split_names[0]
names_clean= split_names[1]

# %% [markdown]
# ##RESULTADO CONSIGNA 1 y 2

# %%
clean_df = pd.DataFrame({'City':df.City, 'Sport':df.Sport, 
                         'Discipline':df.Discipline, 'Event':df.Event, 
                         'Athlete Last Name':split_names[0],
                         'Athlete Name':split_names[1],
                         'Gender':df.Gender, 'Country_Code':df.Country_Code,
                         'Country':df.Country, 'Event_gender':df.Event_gender,
                         'Medal':df.Medal})
clean_df
# Out:
#            City      Sport       Discipline           Event Athlete Last Name  \
# 0      Montreal   Aquatics           Diving  3m springboard            KÖHLER
# 1      Montreal   Aquatics           Diving  3m springboard          KOSENKOV
# 2      Montreal   Aquatics           Diving  3m springboard             BOGGS
# 3      Montreal   Aquatics           Diving  3m springboard          CAGNOTTO
# 4      Montreal   Aquatics           Diving    10m platform            WILSON
# ...         ...        ...              ...             ...               ...
# 15428   Beijing  Wrestling  Wrestling Gre-R       66 - 74kg            GUENOT
# 15429   Beijing  Wrestling  Wrestling Gre-R       66 - 74kg         KVIRKELIA
# 15430   Beijing  Wrestling  Wrestling Gre-R       55 - 60kg           RAHIMOV
# 15431   Beijing  Wrestling  Wrestling Gre-R       60 - 66kg            GUENOT
# 15432   Beijing  Wrestling  Wrestling Gre-R      96 - 120kg             LOPEZ
#
# ...
